# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
saldf = pd.read_csv('/content/drive/MyDrive/car_price_prediction_.csv')

# %%
new_saldf = saldf [["Year","Engine Size","Price"]]
print(new_saldf)
# Out:
#       Year  Engine Size     Price
# 0     2016          2.3  26613.92
# 1     2018          4.4  14679.61
# 2     2013          4.5  44402.61
# 3     2011          4.1  86374.33
# 4     2009          2.6  73577.10
# ...    ...          ...       ...
# 2495  2020          2.4  61384.10
# 2496  2001          5.7  24710.35
# 2497  2021          1.1  29902.45
# 2498  2002          4.5  46085.67
# 2499  2005          4.6  16594.14
#
# [2500 rows x 3 columns]

# %%
{"type":"dataframe","variable_name":"saldf"}
# Out:
# {'type': 'dataframe', 'variable_name': 'saldf'}

# %%
new_saldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         2500 non-null   int64
#  1   Engine Size  2500 non-null   float64
#  2   Price        2500 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 58.7 KB

# %%
new_saldf.isnull().sum()
# Out:
# Year           0
# Engine Size    0
# Price          0
# dtype: int64

# %%
inp = new_saldf[['Year','Engine Size']]
out = new_saldf['Price']

# %%
LR = LinearRegression()

# %%
LR.fit(inp,out)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
LR.predict([[2020, 2.0]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([51547.73373185])
